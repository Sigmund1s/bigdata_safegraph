# %%
import pandas as pd

# %%
df_visitor_daytime = pd.read_parquet("E:/Data460/safegraph/bigdata_safegraph-1/parquet/visitor_daytime_cbgs.parquet", engine='pyarrow')
df_related_same_day = pd.read_parquet("E:/Data460/safegraph/bigdata_safegraph-1/parquet/related_same_day_brand.parquet", engine='pyarrow')
df_popularity_hour = pd.read_parquet("E:/Data460/safegraph/bigdata_safegraph-1/parquet/popularity_by_day.parquet", engine='pyarrow')

# %%
df_related_same_day.head(5)

# We have location of store/brand
# Out:
#               placekey                 startDate                   endDate  \
# 0  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 1  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 2  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 3  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 4  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
#
#       related_same_day_brand  value
# 0                    Walmart   50.0
# 1         Buffalo Wild Wings   50.0
# 2     Sam's Club Fuel Center   50.0
# 3                   QuikTrip   50.0
# 4  P.F. Chang's China Bistro   50.0

# %%
df_visitor_daytime.head(5)
# Out:
#               placekey                 startDate                   endDate  \
# 0  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 1  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 0  227-222@5z6-96f-btv 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 1  227-222@5z6-96f-btv 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 2  227-222@5z6-96f-btv 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
#
#   visitor_daytime_cbgs  value
# 0         401430029003    4.0
# 1         401430012001    4.0
# 0         060650449112    7.0
# 1         060650451181    7.0
# 2         060650451151    6.0

# %%
df_popularity_hour.head(10)
# Out:
#               placekey                 startDate                   endDate  \
# 0  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 1  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 2  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 3  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 4  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 5  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 6  zzw-223@5r8-fqv-xkf 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 0  227-222@5z6-96f-btv 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 1  227-222@5z6-96f-btv 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
# 2  227-222@5z6-96f-btv 2021-07-01 00:00:00+00:00 2021-08-01 00:00:00+00:00
#
#   popularity_by_day  value
# 0            Monday      0
# 1           Tuesday      0
# 2         Wednesday      1
# 3          Thursday      0
# ...
